# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="2df0990fd3bd4e689a7a72f0768f772e", client_secret="0a822461b1934febb3b94cfc58e7df97")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
import pandas as pd

# %%
paylist_link = "https://open.spotify.com/playlist/5ABHKGoOzxkaa28ttQV9sE"

# %%
paylist_link.split("/")[-1]
# Out:
# '5ABHKGoOzxkaa28ttQV9sE'

# %%
paylist_url = paylist_link.split("/")[-1]

# %%
raw_data = sp.playlist_tracks(paylist_url)

# %%
len(raw_data['items'])
# Out:
# 100

# %%
raw_data['items'][0]["track"]["album"]["id"]
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
raw_data['items'][0]["track"]["duration_ms"]
# Out:
# 200040

# %%
raw_data['items'][0]["track"]["album"]["external_urls"]["spotify"]
# Out:
# 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'

# %%
raw_data['items'][0]["track"]["album"]["release_date"]
# Out:
# '2020-03-20'

# %%
raw_data['items'][0]["track"]["album"]["name"]
# Out:
# 'After Hours'

# %%
for row in raw_data['items']:
    album_id = row["track"]["album"]["id"]
    album_name = row["track"]["album"]["name"]
    album_url = row["track"]["album"]["external_urls"]["spotify"]
    album_releasedate = row["track"]["album"]["release_date"]
    print(album_name)
# Out:
# After Hours
# ÷ (Deluxe)
# Starboy
# Divinely Uninspired To A Hellish Extent
# Harry's House
# I Love You.
# Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)
# Views
# F*CK LOVE 3: OVER YOU
# ÷ (Deluxe)
# Don't You Worry Child
# Evolve
# Heat Waves
# lovely (with Khalid)
# Falling
# Closer
# Living In The Pause
# Back from the Edge
# Dance Monkey (Stripped Back) / Dance Monkey
# Memories...Do Not Open
# rockstar
# Dream Your Life Away
# AM
# The Waiting Game
# Parachutes
# Strange Trails
# Long Way Down (Deluxe)
# Hozier (Special Edition)
# Native
# Señorita
# Between The Lines
# Fine Line
# x (Deluxe Edition)
# LIL ANGEL "SHE HER"
# Lover
# SCRAPS
# Future Nostalgia
# The Heist
# Last Name
# Goodbye & Good Riddance
# More Than You Know
# Birds In The Trap Sing McKnight
# Hollywood's Bleeding
# Viva La Vida or Death and All His Friends
# Starboy
# Had My Heart
# HIT ME HARD AND SOFT
# A Night At The Opera (2011 Remaster)
# Purpose (Deluxe)
# ...

# %%
album_list = []
for row in raw_data['items']:
    album_id = row["track"]["album"]["id"]
    album_name = row["track"]["album"]["name"]
    album_url = row["track"]["album"]["external_urls"]["spotify"]
    album_release_date = row["track"]["album"]["release_date"]
    album_track_duration = row["track"]["duration_ms"]
    album_elements = {'album_id' : album_id,'album_name': album_name,'album_url':album_url,'album_release_date': album_release_date,'album_track_duration': album_track_duration}
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'album_name': 'After Hours',
#   'album_url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj',
#   'album_release_date': '2020-03-20',
#   'album_track_duration': 200040},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'album_name': '÷ (Deluxe)',
#   'album_url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu',
#   'album_release_date': '2017-03-03',
#   'album_track_duration': 233712},
#  {'album_id': '09fggMHib4YkOtwQNXEBII',
#   'album_name': 'Starboy',
#   'album_url': 'https://open.spotify.com/album/09fggMHib4YkOtwQNXEBII',
#   'album_release_date': '2016-11-25',
#   'album_track_duration': 230453},
#  {'album_id': '5658aM19fA3JVwTK6eQX70',
#   'album_name': 'Divinely Uninspired To A Hellish Extent',
#   'album_url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70',
#   'album_release_date': '2019-05-17',
#   'album_track_duration': 182160},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
# ...

# %%
raw_data["items"][0]["track"]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#   'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#   'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'type': 'artist',
#   'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}]

# %%
raw_data["items"][0]
# Out:
# {'added_at': '2024-02-15T21:57:53Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#   'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#   'id': 'jonathan.holgersson',
#   'type': 'user',
#   'uri': 'spotify:user:jonathan.holgersson'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
# ...

# %%
artist_list = []
for row in raw_data["items"]:
    for key,value in row.items():
        if key == "track":
            for artist in value["artists"]:
                artist_dict = {'artist_id': artist['id'],'artist_name':artist["name"],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'artist_name': 'Daft Punk',
#   'external_url': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi'},
#  {'artist_id': '4GNC7GD6oZMSxPGyXy4MNB',
#   'artist_name': 'Lewis Capaldi',
#   'external_url': 'https://api.spotify.com/v1/artists/4GNC7GD6oZMSxPGyXy4MNB'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'external_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '77SW9BnxLY8rJ0RciFqkHh',
# ...

# %%
song_list = []
for row in raw_data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'song_name': 'Blinding Lights',
#   'duration_ms': 200040,
#   'url': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b',
#   'popularity': 90,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7qiZfU4dY1lWllzX7mPBI3',
#   'song_name': 'Shape of You',
#   'duration_ms': 233712,
#   'url': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3',
#   'popularity': 90,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '5aAx2yezTd8zXrkmtKl66Z',
#   'song_name': 'Starboy',
#   'duration_ms': 230453,
#   'url': 'https://open.spotify.com/track/5aAx2yezTd8zXrkmtKl66Z',
#   'popularity': 4,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '09fggMHib4YkOtwQNXEBII',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7qEHsqek33rTcFNT9PFqLf',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   album_id              100 non-null    object
#  1   album_name            100 non-null    object
#  2   album_url             100 non-null    object
#  3   album_release_date    100 non-null    object
#  4   album_track_duration  100 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates("album_id")

# %%
artist_df  = pd.DataFrame.from_dict(artist_list)

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    object
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB

# %%
song_df.head()
# Out:
#                   song_id          song_name  duration_ms  \
# 0  0VjIjW4GlUZAMYd2vXMi3b    Blinding Lights       200040
# 1  7qiZfU4dY1lWllzX7mPBI3       Shape of You       233712
# 2  5aAx2yezTd8zXrkmtKl66Z            Starboy       230453
# 3  7qEHsqek33rTcFNT9PFqLf  Someone You Loved       182160
# 4  4Dvkj6JhhA12EX05fT7y2e          As It Was       167303
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0VjIjW4GlUZAMYd...          90
# 1  https://open.spotify.com/track/7qiZfU4dY1lWllz...          90
# 2  https://open.spotify.com/track/5aAx2yezTd8zXrk...           4
# 3  https://open.spotify.com/track/7qEHsqek33rTcFN...          88
# 4  https://open.spotify.com/track/4Dvkj6JhhA12EX0...          89
#
#              song_added                album_id               artist_id
# 0  2024-02-15T21:57:53Z  4yP0hdKOZPNshxUOjY0cZj  1Xyo4u8uXC1ZmMpatF05PJ
# 1  2024-02-15T21:57:53Z  3T4tUhGYeRNVUGevb0wThu  6eUKZXaKkcviH0Ku9w2n3V
# ...

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 1  6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 2  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 3  4tZwfgrHOc3mvqYlEYSvVi      Daft Punk
# 4  4GNC7GD6oZMSxPGyXy4MNB  Lewis Capaldi
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 1  https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 2  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 3  https://api.spotify.com/v1/artists/4tZwfgrHOc3...
# 4  https://api.spotify.com/v1/artists/4GNC7GD6oZM...

# %%
song_df["song_added"] = pd.to_datetime(song_df["song_added"])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
